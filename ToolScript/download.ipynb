# %%
from AlgoTrade.Utils.DataManager import DataManager

# %%
dm = DataManager(name="bitget")

# %%
ohlcv_data_s = dm.download("TRX/USDT:USDT", "15m", "2024-01-01 00:00:00")
# Out:
# fetched ohlcv data for TRX/USDT:USDT from 2024-01-01 00:00:00
# fetched ohlcv data for TRX/USDT:USDT from 2024-01-02 01:00:00
# fetched ohlcv data for TRX/USDT:USDT from 2024-01-03 02:00:00
# fetched ohlcv data for TRX/USDT:USDT from 2024-01-04 03:00:00
# fetched ohlcv data for TRX/USDT:USDT from 2024-01-05 04:00:00
# fetched ohlcv data for TRX/USDT:USDT from 2024-01-06 05:00:00
# fetched ohlcv data for TRX/USDT:USDT from 2024-01-07 06:00:00
# fetched ohlcv data for TRX/USDT:USDT from 2024-01-08 07:00:00
# fetched ohlcv data for TRX/USDT:USDT from 2024-01-09 08:00:00
# fetched ohlcv data for TRX/USDT:USDT from 2024-01-10 09:00:00
# fetched ohlcv data for TRX/USDT:USDT from 2024-01-11 10:00:00
# fetched ohlcv data for TRX/USDT:USDT from 2024-01-12 11:00:00
# fetched ohlcv data for TRX/USDT:USDT from 2024-01-13 12:00:00
# fetched ohlcv data for TRX/USDT:USDT from 2024-01-14 13:00:00
# fetched ohlcv data for TRX/USDT:USDT from 2024-01-15 14:00:00
# ...

# %%
dm.to_local(ohlcv_data_s, "TRX/USDT:USDT", "15m")
# Out:
# Exporting data to d:\ComputerScience\Trading\Quant2\data\bitget\TRX_USDT_USDT_15m.csv...
# Export completed successfully.

# %%
for symbol in dm.available_symbols:
    if symbol.endswith("USDT:USDT"):
        print(symbol)
